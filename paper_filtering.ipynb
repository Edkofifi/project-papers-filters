# %% [markdown]
# ## FILTERING PUBLICATIONS FOR RESEARCH WORK

# %%
import pandas as pd
import bibtexparser
import chardet
import os

# %% [markdown]
# ### Processing Papers from IEEE

# %%
ieee_papers = pd.read_csv("souced/IEEE_final.csv")
ieee_papers.head()
# Out:
#                                       Document Title  \
# 0  Reliability of phantom pain relief in neuroreh...
# 1  Research of interactive experience display of ...
# 2  Investigating Spherical Fish Tank Virtual Real...
# 3  Cooperative node selection scheme based on cre...
# 4  Design of e-commerce logistics distribution pa...
#
#                                              Authors  \
# 0  Y. Sano; A. Ichinose; N. Wake; M. Osumi; M. Su...
# 1                                 W. Zhang; Y. Zhang
# 2         G. Hagemann; Q. Zhou; I. Stavness; S. Fels
# 3                           D. Hao; Y. Chen; Y. Wang
# 4                                             L. Min
#
#                                  Author Affiliations  \
# 0  The Department of Mechano- Informatics, The Un...
# 1  Digital Media Technology, Jiangsu University, ...
# 2  University of British Columbia LMU Munich; Uni...
# 3  Xijing University, Xi’an, China; Xijing Univer...
# 4    Shandong College of Electronic Technology China
#
#                                    Publication Title Date Added To Xplore  \
# 0  2015 37th Annual International Conference of t...           5 Nov 2015
# 1  2020 International Conference on Innovation De...          30 Aug 2021
# 2  2019 IEEE Conference on Virtual Reality and 3D...          15 Aug 2019
# 3  2020 International Conference on Virtual Reali...          21 Sep 2021
# 4  2020 International Conference on Virtual Reali...          21 Sep 2021
#
#    Publication Year  Volume  Issue Start Page End Page  ...  \
# 0              2015     NaN    NaN       2482     2485  ...
# 1              2020     NaN    NaN        367      372  ...
# 2              2019     NaN    NaN        950      951  ...
# 3              2020     NaN    NaN        780      782  ...
# 4              2020     NaN    NaN         38       41  ...
#
#                                           Mesh_Terms Article Citation Count  \
# 0  Humans;Neurological Rehabilitation;Phantom Lim...                    8.0
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    1.0
# 4                                                NaN                    NaN
#
#   Patent Citation Count Reference Count License  Online Date Issue Date  \
# 0                   NaN            18.0    IEEE   5 Nov 2015        NaN
# 1                   NaN            12.0    IEEE  30 Aug 2021        NaN
# 2                   NaN            14.0    IEEE  15 Aug 2019        NaN
# 3                   NaN             6.0    IEEE  21 Sep 2021        NaN
# 4                   NaN            10.0    IEEE  21 Sep 2021        NaN
#
#   Meeting Date Publisher Document Identifier
# 0          NaN      IEEE    IEEE Conferences
# 1          NaN      IEEE    IEEE Conferences
# 2          NaN      IEEE    IEEE Conferences
# 3          NaN      IEEE    IEEE Conferences
# 4          NaN      IEEE    IEEE Conferences
#
# [5 rows x 30 columns]

# %%
ieee_papers.shape
# Out:
# (545, 33)

# %%
ieee_papers["Document Title"].iloc[97]
# Out:
# 'VR-HMD Eye Tracker in Active Visual Field Testing'

# %% [markdown]
# ### Processing Papers from scopus

# %%
scopus_papers = pd.read_csv("souced/Scopus.csv")
scopus_papers.columns
# Out:
# Index(['Authors', 'Author(s) ID', 'Title', 'Year', 'Source title', 'Volume',
#        'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by',
#        'DOI', 'Link', 'Affiliations', 'Authors with affiliations', 'Abstract',
#        'Author Keywords', 'Index Keywords', 'References',
#        'Correspondence Address', 'Editors', 'Sponsors', 'Publisher',
#        'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
scopus_papers["Title"]
# Out:
# 0       5G: A tutorial overview of standards, trials, ...
# 1       Social media and health care professionals: Be...
# 2                            Communications in the 6G Era
# 3               Wireless Network Intelligence at the Edge
# 4       Virtual network functions placement and routin...
#                               ...
# 1995    Novel model-based decision support system for ...
# 1996    NODR: An NOMA-Based Retransmission Scheme for ...
# 1997    Partially Reliable Transport Layer for QUICker...
# 1998    Use of Differential Entropy for Automated Emot...
# 1999    Application and Validation of LUXIE: A Newly D...
# Name: Title, Length: 2000, dtype: object

# %%
scopus_papers.head()
# Out:
#                                              Authors  \
# 0  Shafi M., Molisch A.F., Smith P.J., Haustein T...
# 1                                     Lee Ventola C.
# 2                      Viswanathan H., Mogensen P.E.
# 3       Park J., Samarakoon S., Bennis M., Debbah M.
# 4           Addis B., Belabed D., Bouet M., Secci S.
#
#                                         Author(s) ID  \
# 0  7005892251;7006594890;7406996870;55945252800;5...
# 1                                       35253849000;
# 2                           35511016000;35584209600;
# 3   57195605503;55371219200;23007914800;35588784300;
# 4    9243856400;56428017900;24337489900;24400146200;
#
#                                                Title  Year  \
# 0  5G: A tutorial overview of standards, trials, ...  2017
# 1  Social media and health care professionals: Be...  2014
# 2                       Communications in the 6G Era  2020
# 3          Wireless Network Intelligence at the Edge  2019
# 4  Virtual network functions placement and routin...  2015
#
#                                         Source title Volume Issue Art. No.  \
# 0   IEEE Journal on Selected Areas in Communications     35     6  7894280
# 1                                            P and T     39     7      NaN
# 2                                        IEEE Access      8   NaN  9040431
# 3                            Proceedings of the IEEE    107    11      NaN
# 4  2015 IEEE 4th International Conference on Clou...    NaN   NaN  7335301
#
#   Page start Page end  ...  Language of Original Document  \
# 0       1201     1221  ...                        English
# 1        491  499+520  ...                        English
# 2      57063    57074  ...                        English
# 3       2204     2239  ...                        English
# 4        171      177  ...                        English
#
#                 Abbreviated Source Title     Document Type Publication Stage  \
# 0                IEEE J Sel Areas Commun           Article             Final
# 1                                    P T           Article             Final
# 2                            IEEE Access           Article             Final
# 3                             Proc. IEEE           Article             Final
# 4  IEEE Int. Conf. Cloud Netw., CloudNet  Conference Paper             Final
#
#                Open Access  Source                 EID occurence   keywords  \
# 0  All Open Access, Bronze  Scopus  2-s2.0-85020433200         0         {}
# 1                      NaN  Scopus  2-s2.0-84904422999         0         {}
# 2    All Open Access, Gold  Scopus  2-s2.0-85082804216         0         {}
# 3   All Open Access, Green  Scopus  2-s2.0-85074405954         0         {}
# 4   All Open Access, Green  Scopus  2-s2.0-84960968039        14  {virtual}
#
#   key_words_count
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1
#
# [5 rows x 42 columns]

# %%
scopus_papers.shape
# Out:
# (2000, 39)

# %% [markdown]
# ### Processing Papers from ScienceDirect

# %%
# get the encoding for this file
with open("souced/acm_final.bib", 'rb') as f:
    result = chardet.detect(f.read())

encoding = result['encoding']
encoding

# open the file with the right encoding
with open("souced/acm_final.bib", 'r', encoding=encoding) as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)
print(bib_database)

# %%
# get the encoding for this file
with open("souced/sciencedirect/bibtex/ScienceDirect_citations_1683817183874.bib", 'rb') as f:
    result = chardet.detect(f.read())

encoding = result['encoding']
encoding

# read the three files and combine them,then parse them appropriately

# create a list of the files
science_direct_files = ["ScienceDirect_citations_1683817183874.bib", "ScienceDirect_citations_1683817246772.bib",
                       "ScienceDirect_citations_1683817273865.bib"]


# create an empty list to hold the contents of all .bib files
bib_data_list = []
directory_path = "souced/sciencedirect/bibtex/"

# iterate over the .bib files and read their contents
for file_name in science_direct_files:
    file_path = os.path.join(directory_path, file_name)
    with open(file_path, 'r', encoding= encoding) as bibtex_file:
        bib_data = bibtexparser.load(bibtex_file)
        bib_data_list.append(bib_data)

# %%
len(bib_data_list)
# Out:
# 3

# %%
# Extract data from entries
data = []
for bib_file in bib_data_list:
    for entry in bib_file.entries:
        row = {
            'author(s)': entry.get('author', ''),
            'title': entry.get('title', ''),
            'year': entry.get('year', ''),
            'isbn': entry.get('isbn', ''),
            'publisher': entry.get('publisher', ''),
            'address': entry.get('year', ''),
            'url': entry.get('url', ''),
            'doi': entry.get('doi', ''),
            'abstract': entry.get('abstract', ''),
            'booktitle': entry.get('booktitle', ''),
            'pages': entry.get('pages', ''),
            'numpages': entry.get('numpages', ''),
            'keywords': entry.get('keywords', ''),
            'location': entry.get('location', ''),
            'series': entry.get('series', '')
        }
        data.append(row)

# %%
len(data)
# Out:
# 252

# %%
#convert to dataframe
sciencedirect_papers= pd.DataFrame(data)
sciencedirect_papers.head()
# Out:
#                                            author(s)  \
# 0  Megan Cooper and Danielle Pollock and Jane War...
# 1  Mohsen Soori and Behrooz Arezoo and Mohsen Habibi
# 2  Sharon Farra and Sherrill Smith and DeAnne Fre...
# 3                              Tikhon P. Podshivalov
# 4  Kevin Kantono and Muhammad Syahmeer How and Qi...
#
#                                                title  year isbn publisher  \
# 0  The development of the W A + E R (water immers...  2022
# 1  Dimensional and geometrical errors of three-ax...  2013
# 2  Development of an assessment instrument to eva...  2015
# 3  Improving implementation of the Blockchain tec...  2022
# 4  Design of experiments meets immersive environm...  2022
#
#   address                                                url  \
# 0    2022  https://www.sciencedirect.com/science/article/...
# 1    2013  https://www.sciencedirect.com/science/article/...
# 2    2015  https://www.sciencedirect.com/science/article/...
# 3    2022  https://www.sciencedirect.com/science/article/...
# 4    2022  https://www.sciencedirect.com/science/article/...
#
#                                             doi  \
# 0    https://doi.org/10.1016/j.midw.2022.103298
# 1     https://doi.org/10.1016/j.cad.2013.06.002
# 2    https://doi.org/10.1016/j.nedt.2015.04.010
# 3  https://doi.org/10.1016/j.hitech.2022.100440
# 4   https://doi.org/10.1016/j.appet.2022.106122
#
#                                             abstract booktitle      pages  \
# 0  Background\nSome research attention has been p...               103298
# 1  Virtual machining systems are applying compute...            1306-1313
# 2  Summary\nBackground and Purpose\nNurses must c...            1016-1022
# 3  Difficulties are caused by the introduction of...               100440
# 4  Design of experiments (DOE) is a family of sta...               106122
#
#   numpages                                           keywords location series
# 0           Waterbirth, Water immersion, Choice, Childbirt...
# 1           Virtual machining, Geometric errors, CMM, 3 ax...
# 2           Nursing education, Decontamination, Instrument...
# 3           Dispute, Enterprise, Property rights, Online a...
# 4           Artificial neural network, Immersive environme...

# %% [markdown]
# ### Processing Papers from ACM

# %%
# get the encoding for this file
with open("souced/acm_final.bib", 'rb') as f:
    result = chardet.detect(f.read())

encoding = result['encoding']
encoding

# open the file with the right encoding
with open("souced/acm_final.bib", 'r', encoding=encoding) as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)
print(bib_database)
# Out:
# <bibtexparser.bibdatabase.BibDatabase object at 0x0000022171BDF3A0>

# %%
# Extract data from entries
data = []
for entry in bib_database.entries:
    row = {
        'author(s)': entry.get('author', ''),
        'title': entry.get('title', ''),
        'year': entry.get('year', ''),
        'isbn': entry.get('isbn', ''),
        'publisher': entry.get('publisher', ''),
        'address': entry.get('year', ''),
        'url': entry.get('url', ''),
        'doi': entry.get('doi', ''),
        'abstract': entry.get('abstract', ''),
        'booktitle': entry.get('booktitle', ''),
        'pages': entry.get('pages', ''),
        'numpages': entry.get('numpages', ''),
        'keywords': entry.get('keywords', ''),
        'location': entry.get('location', ''),
        'series': entry.get('series', '')
    }
    data.append(row)

# %%
acm_papers= pd.DataFrame(data)
acm_papers
# Out:
#                                              author(s)  \
# 0    Sagheb, Shahabedin and Liu, Frank Wencheng and...
# 1    Zhang, Dong and Li, Wenhang and Li, Yi and Gon...
# 2    Liang, Hui and Ge, Chao and Liang, Fei and Sun...
# 3    Olade, Ilesanmi and Liang, Hai-Ning and Flemin...
# 4                                        Csutak, Zsolt
# ..                                                 ...
# 995  Hwang, Jinho and Shwartz, Larisa and Wang, Qin...
# 996  Moin, Ali and Nuzzo, Pierluigi and Sangiovanni...
# 997          Mao, Zhijie and Wu, Guangen and Zhou, Lin
# 998  Shin, Hocheol and Noh, Juhwan and Kim, Dohyun ...
# 999  Istomin, Timofei and Iova, Oana and Picco, Gia...
#
#                                                  title  year           isbn  \
# 0    SWISH: A Shifting-Weight Interface of Simulate...  2019  9781450368162
# 1    A Group Activity Analysis Method Based on Imme...  2018  9781450365192
# 2    Training Model of Safe Escape From Fire Based ...  2020  9781450377027
# 3    Exploring the Vulnerabilities and Advantages o...  2020  9781450376945
# 4    Virtual Universes: The Various Impacts of Cons...  2022  9781450397667
# ..                                                 ...   ...            ...
# 995  FIXME: Enhance Software Reliability with Hybri...  2021  9780738146690
# 996       Optimized Design of a Human Intranet Network  2017  9781450349277
# 997  A 6G Oriented High-Throughput Satellite Commun...  2021  9781450389853
# 998  The System That Cried Wolf: Sensor Security An...  2020
# 999  Route or Flood? Reliable and Efficient Support...  2019
#
#                                publisher address  \
# 0    Association for Computing Machinery    2019
# 1    Association for Computing Machinery    2018
# 2    Association for Computing Machinery    2020
# 3    Association for Computing Machinery    2020
# 4    Association for Computing Machinery    2022
# ..                                   ...     ...
# 995                           IEEE Press    2021
# 996  Association for Computing Machinery    2017
# 997  Association for Computing Machinery    2021
# 998  Association for Computing Machinery    2020
# 999  Association for Computing Machinery    2019
#
#                                                    url  \
# 0              https://doi.org/10.1145/3332165.3347870
# 1              https://doi.org/10.1145/3289430.3289443
# 2              https://doi.org/10.1145/3375998.3376013
# 3              https://doi.org/10.1145/3385378.3385385
# 4              https://doi.org/10.1145/3551504.3551515
# ..                                                 ...
# 995  https://doi.org/10.1109/ICSE-SEIP52600.2021.00032
# 996            https://doi.org/10.1145/3061639.3062296
# 997            https://doi.org/10.1145/3487075.3487140
# 998                    https://doi.org/10.1145/3393926
# 999                    https://doi.org/10.1145/3355997
#
#                                    doi  \
# 0              10.1145/3332165.3347870
# 1              10.1145/3289430.3289443
# 2              10.1145/3375998.3376013
# 3              10.1145/3385378.3385385
# 4              10.1145/3551504.3551515
# ..                                 ...
# 995  10.1109/ICSE-SEIP52600.2021.00032
# 996            10.1145/3061639.3062296
# 997            10.1145/3487075.3487140
# 998                    10.1145/3393926
# 999                    10.1145/3355997
#
#                                               abstract  \
# 0    Current VR/AR systems are unable to reproduce ...
# 1    Group activity analysis is important for crowd...
# 2    The popularization of virtual reality equipmen...
# 3    Virtual reality applications are carving out a...
# 4    The so-called post-postmodern cyber era is spe...
# ..                                                 ...
# 995  With the promise of reliability in cloud, more...
# 996  We address the design space exploration of wir...
# 997  The integration of satellite communication sys...
# 998  Fire alarm and signaling systems are a network...
# 999  Modern protocols for wireless sensor networks ...
#
#                                              booktitle      pages numpages  \
# 0    Proceedings of the 32nd Annual ACM Symposium o...  751‚Äì761       11
# 1    Proceedings of the 2018 2nd International Conf...  110‚Äì113        4
# 2    Proceedings of the 2019 8th International Conf...  168‚Äì175        8
# 3    Proceedings of the 2020 4th International Conf...    45‚Äì52        8
# 4    Proceedings of the Central and Eastern Europea...    69‚Äì72        4
# ..                                                 ...        ...      ...
# 995  Proceedings of the 43rd International Conferen...  228‚Äì237       10
# 996  Proceedings of the 54th Annual Design Automati...                   6
# 997  Proceedings of the 5th International Conferenc...                   5
# 998                                                                     32
# 999                                                                     41
#
#                                               keywords  \
# 0    ungrounded haptic feedback, fluid dynamics, vi...
# 1    Emergency Management, Virtual Geographic Envir...
# 2    safety training, Virtual reality, disaster eva...
# 3    Authentication, Security, Pattern, Virtual rea...
# 4    Digital technologies, Media literacy, News awa...
# ..                                                 ...
# 995  cloud, event management, event correlation, hy...
# 996
# 997  MAPSK, 6G wireless communication, Bit error ra...
# 998  fire alarm and signaling system, sensing and a...
# 999  Wireless sensor networks, actuation, routing p...
#
#                    location         series
# 0      New Orleans, LA, USA       UIST '19
# 1            Beijing, China     BDIOT 2018
# 2            Luoyang, China      ICNCC '19
# 3    Sydney, NSW, Australia    ICVARS 2020
# 4         Budapest, Hungary    CEEeGov '22
# ..                      ...            ...
# 995    Virtual Event, Spain  ICSE-SEIP '21
# 996         Austin, TX, USA        DAC '17
# 997            Sanya, China       CSAE '21
# 998
# 999
#
# [1000 rows x 15 columns]

# %% [markdown]
# #### Access and clean the data

# %%
acm_papers["pages"]
# Out:
# 0      751‚Äì761
# 1      110‚Äì113
# 2      168‚Äì175
# 3        45‚Äì52
# 4        69‚Äì72
#          ...
# 995    228‚Äì237
# 996
# 997
# 998
# 999
# Name: pages, Length: 1000, dtype: object

# %%
acm_papers['pages'] = acm_papers['pages'].str.replace('‚Äì', '-')

# %%
acm_papers["pages"]
# Out:
# 0      751-761
# 1      110-113
# 2      168-175
# 3        45-52
# 4        69-72
#         ...
# 995    228-237
# 996
# 997
# 998
# 999
# Name: pages, Length: 1000, dtype: object

# %%
# save to csv

acm_papers.to_csv("souced/acm_papers.csv")

# %% [markdown]
# ### Processing papers from science direct

# %% [markdown]
# ### Filtering Papers

# %%
'''
Create a search function that computes percentage occurence of keywords in the title/abstract.
We extract document with occurence level that is passed as an argument into the function.
'''
search_keywords = ['trustworthiness', 'reliability', 'mixed', 'virtual', 'reality', 'credibility', 'immersion']
def filter_papers(document, keywords, column, acceptance_rate):
    document["occurence"]= 0
    document["keywords"] = None
    document["key_words_count"]= 0
    percent = []
    count = []
    for index in range(len(document)):
        #doc = document[index].lower()
        words_in_title = document[column].iloc[index].lower().replace(",", " ").split(" ")
        keywords_found = []
        for word in keywords:
            if word in words_in_title:
                keywords_found.append(word)
        keyword_unique = set(keywords_found)
        percent_occurrence = round((len(keyword_unique) / len(keywords)) * 100)
        percent.append(percent_occurrence)
        cnt = len(keyword_unique)
        count.append(cnt)
        document.at[index, 'occurence'] = percent_occurrence
        document.at[index, 'keywords'] = keyword_unique
        document.at[index, 'key_words_count'] = int(cnt)
    
    document = document.sort_values('occurence', ascending=False)

    
    # select documents more 20% occurence level
    selected_docs = document[document["occurence"] > acceptance_rate]
    
    return selected_docs

# %% [markdown]
# ### Filtering the IEEE papers with an acceptance occurence rate of 20%

# %%
ieee_papers_title_filters = filter_papers(ieee_papers, search_keywords, "Document Title", 20)

# %%
ieee_papers_title_filters.to_csv("title_only.csv")

# %%
ieee_papers_title_filters["Document Title"]
# Out:
# 5     The Effect of Virtual Humans Making Verbal Com...
# 0     Reliability of phantom pain relief in neuroreh...
# 62    A Basic Psychophysics Study of Sound Reliabili...
# 33    On the Reliability of Wireless Virtual Reality...
# 34    Virtual Reality based test batteries for evalu...
#                             ...
# 4     Design of e-commerce logistics distribution pa...
# 25    Utilizing Virtual Reality to Enhance the Digit...
# 6     The Effects of a Stressful Physical Environmen...
# 53    Interaction techniques using head gaze for vir...
# 52    Correction Method of Key Movements in Basketba...
# Name: Document Title, Length: 102, dtype: object

# %%
ieee_papers_title_filters["Document Title"].iloc[97]
# Out:
# 'Design of e-commerce logistics distribution path display system based on virtual reality technology'

# %% [markdown]
# #### Filtering Based on the Abstract, with acceptance occurence rate of more than 40%.
# <br>
# To perform the advanced filtering on the the selected titles based on the IEEE title filtering, we used those papers selected and filtered based on the abstract.

# %%
ieee_papers_title_filters.columns
# Out:
# Index(['Document Title', 'Authors', 'Author Affiliations', 'Publication Title',
#        'Date Added To Xplore', 'Publication Year', 'Volume', 'Issue',
#        'Start Page', 'End Page', 'Abstract', 'ISSN', 'ISBNs', 'DOI',
#        'Funding Information', 'PDF Link', 'Author Keywords', 'IEEE Terms',
#        'INSPEC Controlled Terms', 'INSPEC Non-Controlled Terms', 'Mesh_Terms',
#        'Article Citation Count', 'Patent Citation Count', 'Reference Count',
#        'License', 'Online Date', 'Issue Date', 'Meeting Date', 'Publisher',
#        'Document Identifier', 'occurence', 'keywords', 'key_words_count'],
#       dtype='object')

# %%
ieee_papers_title=pd.read_csv("title_only.csv")
ieee_papers_title.sample(10)
# Out:
#      Unnamed: 0                                     Document Title  \
# 34          375  Situation display system of USV auxiliary navi...
# 20           89  Correction Method of Basketball Shooting Error...
# 55          140  Monitoring virtual metrology reliability in a ...
# 7           103  Application of Internet of Things and Virtual ...
# 90           21  A maintenance influencing factor evaluation me...
# 101          52  Correction Method of Key Movements in Basketba...
# 52          143  Touching The Droid: Understanding and Improvin...
# 63           27  Virtual Reality Experience in Tourism: A Facto...
# 54          141  Building Trust in Autonomous Vehicles: Role of...
# 79           39  The Difference in Measuring Reachability Dista...
#
#                                                Authors  \
# 34                           L. Zhang; Y. Zhao; Y. Fan
# 20                                      W. Yang; H. Yi
# 55                        D. Kurz; C. De Luca; J. Pilz
# 7                             Y. Ding; Y. Li; L. Cheng
# 90              C. Dai; S. Wu; Q. Tang; S. Liu; B. Liu
# 101                                  Y. Huang; W. Yang
# 52               F. Zhu; Z. Lyu; M. Sousa; T. Grossman
# 63   L. Kusdibyo; A. Brien; R. Sutrisno; D. Suhartanto
# 54   L. Morra; F. Lamberti; F. G. Pratticó; S. L. R...
# 79                         W. Xiong; X. Yu; Y. -C. Lee
#
#                                    Author Affiliations  \
# 34   College of Marine Electrical Engineering, Dali...
# 20   Nan Chang Business College of Jxau, Gongqing C...
# 55   Alpen-Adria University (AAU) of Klagenfurt Inf...
# 7    Department of Physical Education, Northwest Un...
# 90   Quality and Reliability Center, CSSC China Ins...
# 101  Nan Chang Business, College of Jxau, Gongqingc...
# 52   Department of Computer Science, University of ...
# 63   Politeknik Negeri Bandung,Department of Busine...
# 54   Dipartimento di Automatica e Informatica, Poli...
# 79   School of Design, South China University of Te...
#
#                                      Publication Title Date Added To Xplore  \
# 34   2022 7th International Conference on Automatio...          25 Jul 2022
# 20   2022 Global Reliability and Prognostics and He...          14 Nov 2022
# 55   2013 IEEE International Conference on Automati...           7 Nov 2013
# 7                                          IEEE Access           2 Jun 2020
# 90   12th International Conference on Quality, Reli...          28 Apr 2023
# 101  2022 Global Reliability and Prognostics and He...          14 Nov 2022
# 52   2022 IEEE International Symposium on Mixed and...          27 Dec 2022
# 63   2021 IEEE International Conference on Industry...          17 Sep 2021
# 54           IEEE Transactions on Vehicular Technology          21 Oct 2019
# 79   2020 IEEE 7th International Conference on Indu...          27 May 2020
#
#      Publication Year  Volume  Issue  Start Page  ...  Reference Count  \
# 34               2022     NaN    NaN         245  ...             12.0
# 20               2022     NaN    NaN           1  ...             15.0
# 55               2013     NaN    NaN          20  ...              6.0
# 7                2020     8.0    NaN       96065  ...             30.0
# 90               2022  2022.0    NaN        1920  ...              NaN
# 101              2022     NaN    NaN           1  ...             15.0
# 52               2022     NaN    NaN         807  ...             52.0
# 63               2021     NaN    NaN          27  ...             29.0
# 54               2019    68.0   10.0        9438  ...             55.0
# 79               2020     NaN    NaN         390  ...             16.0
#
#     License  Online Date Issue Date Meeting Date Publisher  \
# 34     IEEE  25 Jul 2022        NaN          NaN      IEEE
# 20     IEEE  14 Nov 2022        NaN          NaN      IEEE
# 55     IEEE   7 Nov 2013        NaN          NaN      IEEE
# 7      CCBY  11 May 2020        NaN          NaN      IEEE
# 90      NaN  28 Apr 2023        NaN          NaN       IET
# 101    IEEE  14 Nov 2022        NaN          NaN      IEEE
# 52     IEEE  27 Dec 2022        NaN          NaN      IEEE
# 63     IEEE  17 Sep 2021        NaN          NaN      IEEE
# 54     IEEE   6 Aug 2019        NaN          NaN      IEEE
# 79     IEEE  27 May 2020        NaN          NaN      IEEE
#
#     Document Identifier occurence                    keywords key_words_count
# 34     IEEE Conferences        29      {'virtual', 'reality'}               2
# 20     IEEE Conferences        29      {'virtual', 'reality'}               2
# 55     IEEE Conferences        29  {'reliability', 'virtual'}               2
# 7         IEEE Journals        29      {'virtual', 'reality'}               2
# 90      IET Conferences        29      {'virtual', 'reality'}               2
# 101    IEEE Conferences        29      {'virtual', 'reality'}               2
# 52     IEEE Conferences        29      {'virtual', 'reality'}               2
# 63     IEEE Conferences        29      {'virtual', 'reality'}               2
# 54        IEEE Journals        29      {'virtual', 'reality'}               2
# 79     IEEE Conferences        29      {'virtual', 'reality'}               2
#
# [10 rows x 34 columns]

# %%
ieee_selected = ieee_papers_title_filters
advanced_ieee_filter= filter_papers(ieee_papers_title, search_keywords, 'Abstract', 40)

# %%
advanced_ieee_filter.head()
# Out:
#     Unnamed: 0                                     Document Title  \
# 0            5  The Effect of Virtual Humans Making Verbal Com...
# 76          42  Towards Artificial Intelligence Driven Immersi...
# 12         112  Measurements of live actor motion in mixed rea...
# 43         184  Evaluation of the potential impact of fully-im...
# 48         168  A Framework of Student's Learning Motivation i...
#
#                                               Authors  \
# 0   J. Stuart; K. Aul; M. D. Bumbach; A. Stephen; ...
# 76   S. Alsaleh; A. Tepljakov; M. Tamre; E. Petlenkov
# 12                   G. Hough; I. Williams; C. Athwal
# 43                                A. Maffei; M. Onori
# 48  K. Cheng; A. M. Zaini; D. C. d. Wong; H. Chong...
#
#                                   Author Affiliations  \
# 0   University of Florida; University of Florida; ...
# 76  Department of Electrical Power Engineering and...
# 12  Faculty of Technology, Engineering and the Env...
# 43  Department of Production Engineering, KTH Roya...
# 48  De Institute of Creative Arts and Design, UCSI...
#
#                                     Publication Title Date Added To Xplore  \
# 0   2022 IEEE Conference on Virtual Reality and 3D...          20 Apr 2022
# 76  2021 44th International Conference on Telecomm...          30 Aug 2021
# 12  2014 IEEE International Symposium on Mixed and...           6 Nov 2014
# 43                                  2019 IEEE AFRICON           7 Jul 2020
# 48  2022 10th International Conference on Informat...          21 Oct 2022
#
#     Publication Year  Volume  Issue  Start Page  ...  Reference Count License  \
# 0               2022     NaN    NaN         455  ...             33.0    IEEE
# 76              2021     NaN    NaN         340  ...             16.0    IEEE
# 12              2014     NaN    NaN          99  ...              NaN    IEEE
# 43              2019     NaN    NaN           1  ...             18.0    IEEE
# 48              2022     NaN    NaN          70  ...             36.0    IEEE
#
#     Online Date Issue Date Meeting Date Publisher Document Identifier  \
# 0   20 Apr 2022        NaN          NaN      IEEE    IEEE Conferences
# 76  30 Aug 2021        NaN          NaN      IEEE    IEEE Conferences
# 12   6 Nov 2014        NaN          NaN      IEEE    IEEE Conferences
# 43   7 Jul 2020        NaN          NaN      IEEE    IEEE Conferences
# 48  21 Oct 2022        NaN          NaN      IEEE    IEEE Conferences
#
#    occurence                                           keywords  \
# 0         86  {trustworthiness, reliability, credibility, mi...
# 76        57         {immersion, virtual, reality, credibility}
# 12        57             {mixed, virtual, reality, credibility}
# 43        57         {reliability, immersion, virtual, reality}
# 48        57       {reliability, virtual, reality, credibility}
#
#    key_words_count
# 0                6
# 76               4
# 12               4
# 43               4
# 48               4
#
# [5 rows x 34 columns]

# %%
advanced_ieee_filter["Document Title"].iloc[50]
# Out:
# 'Design and application of intelligent patrol system based on virtual reality'

# %% [markdown]
# #### Save the papers after the advanced the search

# %%
advanced_ieee_filter.to_csv("filtered_papers/final_ieee_papers.csv", index=False)

# %% [markdown]
# ### Filtering the ACM papers with an acceptance occurence rate of 20%

# %%
acm_papers.sample(5)
# Out:
#                                              author(s)  \
# 183  Stojmenovi\'{c}, Milica and Spero, Eric and St...
# 319           Nisiotis, Louis and Kleanthous, Styliani
# 489           Chowdhury, Abishi and Tripathi, Priyanka
# 486  Liu, Shudong and Li, Xiaoli and Xiang, Shili a...
# 399                   White, Ryen W. and Hassan, Ahmed
#
#                                                  title  year           isbn  \
# 183                        What is Beautiful is Secure  2022
# 319  The Relationship Between Students' Engagement ...  2019  9781450368957
# 489  A Novel Attempt towards Effective Scheduling B...  2014  9781450332163
# 486  Mobile Robot Routing with Energy Consumption O...  2020  9781450372350
# 399               Content Bias in Online Health Search  2014
#
#                                publisher address  \
# 183  Association for Computing Machinery    2022
# 319  Association for Computing Machinery    2019
# 489  Association for Computing Machinery    2014
# 486  Association for Computing Machinery    2020
# 399  Association for Computing Machinery    2014
#
#                                          url                      doi  \
# 183          https://doi.org/10.1145/3533047          10.1145/3533047
# 319  https://doi.org/10.1145/3304221.3319743  10.1145/3304221.3319743
# 489  https://doi.org/10.1145/2677855.2677891  10.1145/2677855.2677891
# 486  https://doi.org/10.1145/3373724.3373739  10.1145/3373724.3373739
# 399          https://doi.org/10.1145/2663355          10.1145/2663355
#
#                                               abstract  \
# 183  Visual appeal has been shown to influence perc...
# 319  The use of educational Multi-User Virtual Envi...
# 489  Cloud computing is now becoming a trend of mod...
# 486  We consider scheduling mobile robots which are...
# 399  Search engines help people answer consequentia...
#
#                                              booktitle  pages numpages  \
# 183                                                                 30
# 319  Proceedings of the 2019 ACM Conference on Inno...  71-77        7
# 489  Proceedings of the 2014 International Conferen...               6
# 486  Proceedings of the 5th International Conferenc...  30-35        6
# 399                                                                 33
#
#                                               keywords  \
# 183  Aesthetics, web certificates, visual appeal, h...
# 319  virtual worlds, engagement, transactive memory...
# 489  Virtual Machine, Reliability, Priority, Datace...
# 486  Industrial internet of things, Intelligent man...
# 399                      health search, Content biases
#
#                       location      series
# 183
# 319      Aberdeen, Scotland Uk  ITiCSE '19
# 489  Udaipur, Rajasthan, India   ICTCS '14
# 486       Singapore, Singapore   ICRAI '19
# 399

# %%
acm_papers.columns
# Out:
# Index(['author(s)', 'title', 'year', 'isbn', 'publisher', 'address', 'url',
#        'doi', 'abstract', 'booktitle', 'pages', 'numpages', 'keywords',
#        'location', 'series'],
#       dtype='object')

# %%
acm_papers_title_filters = filter_papers(acm_papers, search_keywords, "title", 20)

# %%
acm_papers_title_filters.tail()
# Out:
#                                              author(s)  \
# 65                             Gomez-Rodriguez, Manuel
# 66   Tabibian, Behzad and Valera, Isabel and Farajt...
# 5    Clark, Andrew and Pillay, Anban W. and Moodley...
# 212  Kawahara, Ayumu and Noguchi, Yohei and Tanaka,...
# 960  Cipresso, Pietro and Serino, Silvia and Pedrol...
#
#                                                  title  year           isbn  \
# 65   Distilling Information Reliability and Source ...  2017  9781450349147
# 66   Distilling Information Reliability and Source ...  2017  9781450349130
# 5    A System for Pose Analysis and Selection in Vi...  2020  9781450388474
# 212  A Virtual Agent That is Equipped With Internal...  2022
# 960  Psychometric Reliability of the NeuroVR-Based ...  2013  9781936968800
#
#                                              publisher address  \
# 65   International World Wide Web Conferences Steer...    2017
# 66   International World Wide Web Conferences Steer...    2017
# 5                  Association for Computing Machinery    2020
# 212                                         IEEE Press    2022
# 960  ICST (Institute for Computer Sciences, Social-...    2013
#
#                                                    url  \
# 65             https://doi.org/10.1145/3041021.3054760
# 66             https://doi.org/10.1145/3038912.3052672
# 5              https://doi.org/10.1145/3410886.3410909
# 212
# 960  https://doi.org/10.4108/icst.pervasivehealth.2...
#
#                                           doi  \
# 65                    10.1145/3041021.3054760
# 66                    10.1145/3038912.3052672
# 5                     10.1145/3410886.3410909
# 212
# 960  10.4108/icst.pervasivehealth.2013.252361
#
#                                               abstract  \
# 65   Online knowledge repositories typically rely o...
# 66   Online knowledge repositories typically rely o...
# 5    Depth cameras provide a natural and intuitive ...
# 212  When interacting with humans, virtual agents u...
# 960  This stusdy aim at testing the psychometric re...
#
#                                              booktitle    pages numpages  \
# 65   Proceedings of the 26th International Conferen...     1513        1
# 66   Proceedings of the 26th International Conferen...  847-855        9
# 5    Conference of the South African Institute of C...  210-216        7
# 212  Proceedings of the 2022 ACM/IEEE International...  844-846        3
# 960  Proceedings of the 7th International Conferenc...  446-449        4
#
#                            keywords                  location  \
# 65   {reliability, trustworthiness}          Perth, Australia
# 66   {reliability, trustworthiness}          Perth, Australia
# 5                {virtual, reality}   Cape Town, South Africa
# 212          {virtual, credibility}  Sapporo, Hokkaido, Japan
# 960          {reliability, virtual}             Venice, Italy
#
#                   series  occurence  key_words_count
# 65     WWW '17 Companion         29                2
# 66               WWW '17         29                2
# 5            SAICSIT '20         29                2
# 212              HRI '22         29                2
# 960  PervasiveHealth '13         29                2

# %%
acm_papers_title_filters.shape
# Out:
# (24, 17)

# %%
acm_papers_title_filters.to_csv("acm_title_filters_result.csv")

# %% [markdown]
# #### Filtering Based on the Abstract, with acceptance occurence rate of more than 40%.

# %%
#load the acm title results that was saved
acm_title_results=pd.read_csv("acm_title_filters_result.csv")

# %%
acm_title_results.sample(5)
# Out:
#     Unnamed: 0                                          author(s)  \
# 7          687  Pellegrini, Andrea and Greathouse, Joseph L. a...
# 5           38  Sendhilnathan, Naveen and Zhang, Ting and Lafr...
# 1           22  Suhonen, Katja and V\"{a}\"{a}n\"{a}nen-Vainio...
# 19          65                            Gomez-Rodriguez, Manuel
# 0           13  Houzangbe, Samory and Christmann, Olivier and ...
#
#                                                 title  year          isbn  \
# 7   Viper: Virtual Pipelines for Enhanced Reliability  2012  9.781450e+12
# 5   Detecting Input Recognition Errors and User Er...  2022  9.781450e+12
# 1   Two User Studies on Creation and Evaluation of...  2012  9.781450e+12
# 19  Distilling Information Reliability and Source ...  2017  9.781450e+12
# 0   Integrability and Reliability of Smart Wearabl...  2018  9.781450e+12
#
#                                             publisher  address  \
# 7                               IEEE Computer Society     2012
# 5                 Association for Computing Machinery     2022
# 1                 Association for Computing Machinery     2012
# 19  International World Wide Web Conferences Steer...     2017
# 0                 Association for Computing Machinery     2018
#
#                                         url                      doi  \
# 7                                       NaN                      NaN
# 5   https://doi.org/10.1145/3526113.3545628  10.1145/3526113.3545628
# 1   https://doi.org/10.1145/2254556.2254665  10.1145/2254556.2254665
# 19  https://doi.org/10.1145/3041021.3054760  10.1145/3041021.3054760
# 0   https://doi.org/10.1145/3234253.3234305  10.1145/3234253.3234305
#
#                                              abstract  \
# 7   The reliability of future processors is threat...
# 5   Gesture-based recognition systems are suscepti...
# 1   Mixed reality (MR) technologies and applicatio...
# 19  Online knowledge repositories typically rely o...
# 0   Virtual Reality (VR) is now an affordable tech...
#
#                                             booktitle    pages  numpages  \
# 7   Proceedings of the 39th Annual International S...  344-355        12
# 5   Proceedings of the 35th Annual ACM Symposium o...      NaN        19
# 1   Proceedings of the International Working Confe...  588-595         8
# 19  Proceedings of the 26th International Conferen...     1513         1
# 0   Proceedings of the Virtual Reality Internation...      NaN         6
#
#                                  keywords             location  \
# 7              {'reliability', 'virtual'}     Portland, Oregon
# 5                  {'virtual', 'reality'}        Bend, OR, USA
# 1                    {'mixed', 'reality'}  Capri Island, Italy
# 19     {'reliability', 'trustworthiness'}     Perth, Australia
# 0   {'reliability', 'virtual', 'reality'}        Laval, France
#
#                series  occurence  key_words_count
# 7            ISCA '12         29                2
# 5            UIST '22         29                2
# 1             AVI '12         29                2
# 19  WWW '17 Companion         29                2
# 0            VRIC '18         43                3

# %%
#filter on the abstract column
abstract_acm_filter= filter_papers(acm_title_results, search_keywords, 'abstract', 40)

# %%
abstract_acm_filter
# Out:
#    Unnamed: 0                                          author(s)  \
# 3          42               Chakareski, Jacob and Khan, Mahmudur
# 4          40  Zhang, Ting and Hu, Zhenhong and Gupta, Aakar ...
# 1          22  Suhonen, Katja and V\"{a}\"{a}n\"{a}nen-Vainio...
#
#                                                title  year          isbn  \
# 3  Wifi-VLC Dual Connectivity Streaming System fo...  2021  9.781450e+12
# 4  RIDS: Implicit Detection of a Selection Gestur...  2022  9.781450e+12
# 1  Two User Studies on Creation and Evaluation of...  2012  9.781450e+12
#
#                              publisher  address  \
# 3  Association for Computing Machinery     2021
# 4  Association for Computing Machinery     2022
# 1  Association for Computing Machinery     2012
#
#                                        url                      doi  \
# 3  https://doi.org/10.1145/3458306.3460999  10.1145/3458306.3460999
# 4  https://doi.org/10.1145/3526113.3545701  10.1145/3526113.3545701
# 1  https://doi.org/10.1145/2254556.2254665  10.1145/2254556.2254665
#
#                                             abstract  \
# 3  We investigate a future WiFi-VLC dual connecti...
# 4  Freehand interactions with augmented and virtu...
# 1  Mixed reality (MR) technologies and applicatio...
#
#                                            booktitle    pages  numpages  \
# 3  Proceedings of the 31st ACM Workshop on Networ...  106-113         8
# 4  Proceedings of the 35th Annual ACM Symposium o...      NaN        12
# 1  Proceedings of the International Working Confe...  588-595         8
#
#                           keywords             location       series  \
# 3  {reliability, virtual, reality}     Istanbul, Turkey  NOSSDAV '21
# 4  {reliability, virtual, reality}        Bend, OR, USA     UIST '22
# 1    {reliability, mixed, reality}  Capri Island, Italy      AVI '12
#
#    occurence  key_words_count
# 3         43                3
# 4         43                3
# 1         43                3

# %%
abstract_acm_filter.to_csv("filtered_papers/final_acm_papers.csv", index=False)

# %% [markdown]
# ### Filtering the Scopus papers (titles) with an acceptance occurence rate of 20%

# %%
scopus_papers.sample(2)
# Out:
#                                                Authors  \
# 59   Chekired D.A., Togou M.A., Khoukhi L., Ksentin...
# 177                     Tsao L.C., Wu M.W., Chang S.Y.
#
#                                          Author(s) ID  \
# 59   57194875472;56398566800;55978551900;55883979600;
# 177               7005117796;55631841600;42961251100;
#
#                                                  Title  Year  \
# 59   5G-Slicing-Enabled Scalable SDN Core Network: ...  2019
# 177  Effect of TiO 2 nanoparticles on the microstru...  2012
#
#                                           Source title Volume Issue Art. No.  \
# 59    IEEE Journal on Selected Areas in Communications     37     8  8759041
# 177  Journal of Materials Science: Materials in Ele...     23     3      NaN
#
#     Page start Page end  ...  ISBN  CODEN PubMed ID  \
# 59        1769     1782  ...   NaN  ISACE       NaN
# 177        681      687  ...   NaN    NaN       NaN
#
#     Language of Original Document    Abbreviated Source Title Document Type  \
# 59                        English     IEEE J Sel Areas Commun       Article
# 177                       English  J Mater Sci Mater Electron       Article
#
#     Publication Stage Open Access  Source                 EID
# 59              Final         NaN  Scopus  2-s2.0-85069512999
# 177             Final         NaN  Scopus  2-s2.0-84859721091
#
# [2 rows x 39 columns]

# %%
# filter out the titles with the search keywords 
scopus_papers_title_filter = filter_papers(scopus_papers, search_keywords, "Title", 20)
scopus_papers_title_filter
# Out:
#                                                 Authors  \
# 1503                          Polechoński J., Langer A.
# 231   Besnard J., Richard P., Banville F., Nolin P.,...
# 612   Lim H.K., Ji K., Woo Y.S., Han D.-U., Lee D.-H...
# 211   Jacobsen M.E., Andersen M.J., Hansen C.O., Kon...
# 103               Buxbaum L.J., Dawson A.M., Linsley D.
# ...                                                 ...
# 56               Mehta D., Siddiqui M.F.H., Javaid A.Y.
# 227   Chaccour C., Soorki M.N., Saad W., Bennis M., ...
# 86    Kourtesis P., Collina S., Doumas L.A.A., MacPh...
# 210   Atienza R., Blonna R., Saludares M.I., Casimir...
# 147   Lavorgna L., Cervino G., Fiorillo L., Di Leo G...
#
#                                            Author(s) ID  \
# 1503                           55735206300;57753782200;
# 231   36494043800;57210457077;56926850400;6602315939...
# 612   25223234700;57208223594;57220106097;5721753269...
# 211    57194656804;56184137700;56737352900;36704959000;
# 103                 7003860731;19634338000;57723159800;
# ...                                                 ...
# 56                 57201696200;57200536077;55613342900;
# 227   57210337961;57190300884;57203259001;2300791480...
# 86     57210959726;35309731500;12345301900;57212061035;
# 210   8220749100;56118729200;57191621392;57191608798...
# 147   57212467618;54882146400;57191481018;2398843490...
#
#                                                   Title  Year  \
# 1503  Assessment of the Relevance and Reliability of...  2022
# 231   Virtual reality and neuropsychological assessm...  2016
# 612   Test-retest reliability of the virtual reality...  2021
# 211   Testing basic competency in knee arthroscopy u...  2015
# 103   Reliability and validity of the virtual realit...  2012
# ...                                                 ...   ...
# 56    Facial emotion recognition: A survey and real-...  2018
# 227   Risk-Based Optimization of Virtual Reality ove...  2020
# 86    Technological Competence Is a Pre-condition fo...  2019
# 210   Interaction techniques using head gaze for vir...  2016
# 147   Reliability of a virtual prosthodontic project...  2019
#
#                                            Source title     Volume Issue  \
# 1503                                            Sensors         22    13
# 231                       Applied Neuropsychology:Adult         23     3
# 612                                Neuroscience Letters        743   NaN
# 211   Journal of Bone and Joint Surgery - American V...         97     9
# 103                                     Neuropsychology         26     4
# ...                                                 ...        ...   ...
# 56                                Sensors (Switzerland)         18     2
# 227     IEEE International Conference on Communications  2020-June   NaN
# 86                      Frontiers in Human Neuroscience         13   NaN
# 210   Proceedings - 2016 IEEE Region 10 Symposium, T...        NaN   NaN
# 147   International Journal of Environmental Researc...         16    24
#
#      Art. No. Page start Page end  ...  Language of Original Document  \
# 1503     4762        NaN      NaN  ...                        English
# 231       NaN        223      235  ...                        English
# 612    135589        NaN      NaN  ...                        English
# 211       NaN        775      781  ...                        English
# 103       NaN        430      441  ...                        English
# ...       ...        ...      ...  ...                            ...
# 56        416        NaN      NaN  ...                        English
# 227   9149411        NaN      NaN  ...                        English
# 86        342        NaN      NaN  ...                        English
# 210   7519387        110      114  ...                        English
# 147      5139        NaN      NaN  ...                        English
#
#                  Abbreviated Source Title     Document Type Publication Stage  \
# 1503                              Sensors           Article             Final
# 231             Appl. Neuropsychol. Adult           Article             Final
# 612                       Neurosci. Lett.           Article             Final
# 211            J. Bone Jt. Surg. Am. Vol.           Article             Final
# 103                       Neuropsychology           Article             Final
# ...                                   ...               ...               ...
# 56                                Sensors           Article             Final
# 227                  IEEE Int Conf Commun  Conference Paper             Final
# 86                 Front. Human Neurosci.            Review             Final
# 210      Proc. - IEEE Reg. Symp., TENSYMP  Conference Paper             Final
# 147   Int. J. Environ. Res. Public Health           Article             Final
#
#                        Open Access  Source                 EID occurence  \
# 1503  All Open Access, Gold, Green  Scopus  2-s2.0-85132439279        57
# 231                            NaN  Scopus  2-s2.0-84946949625        43
# 612   All Open Access, Hybrid Gold  Scopus  2-s2.0-85098555231        43
# 211                            NaN  Scopus  2-s2.0-84937965598        43
# 103                            NaN  Scopus  2-s2.0-84871701829        43
# ...                            ...     ...                 ...       ...
# 56    All Open Access, Gold, Green  Scopus  2-s2.0-85041521391        29
# 227         All Open Access, Green  Scopus  2-s2.0-85089417620        29
# 86    All Open Access, Gold, Green  Scopus  2-s2.0-85075817785        29
# 210                            NaN  Scopus  2-s2.0-84992029140        29
# 147   All Open Access, Gold, Green  Scopus  2-s2.0-85076760744        29
#
#                                     keywords key_words_count
# 1503  {virtual, reality, reliability, mixed}               4
# 231          {virtual, reality, reliability}               3
# 612          {virtual, reality, reliability}               3
# 211          {virtual, reality, reliability}               3
# 103          {virtual, reality, reliability}               3
# ...                                      ...             ...
# 56                          {reality, mixed}               2
# 227                       {virtual, reality}               2
# 86                        {virtual, reality}               2
# 210                       {virtual, reality}               2
# 147                   {virtual, reliability}               2
#
# [277 rows x 42 columns]

# %%
scopus_papers_title_filter.to_csv("scopus_title_filter_result.csv")

# %% [markdown]
# #### Filtering Based on the Abstract, with acceptance occurence rate of more than 40%.

# %%
#Filtering-Based-on-the-Abstract,-with-acceptance-occurence-rate-of-more-than-40%.# load the saved title result
scopus_title_filter_result = pd.read_csv("scopus_title_filter_result.csv")
scopus_title_filter_result.head()
# Out:
#    Unnamed: 0                                            Authors  \
# 0        1503                          Polechoński J., Langer A.
# 1         231  Besnard J., Richard P., Banville F., Nolin P.,...
# 2         612  Lim H.K., Ji K., Woo Y.S., Han D.-U., Lee D.-H...
# 3         211  Jacobsen M.E., Andersen M.J., Hansen C.O., Kon...
# 4         103              Buxbaum L.J., Dawson A.M., Linsley D.
#
#                                         Author(s) ID  \
# 0                           55735206300;57753782200;
# 1  36494043800;57210457077;56926850400;6602315939...
# 2  25223234700;57208223594;57220106097;5721753269...
# 3   57194656804;56184137700;56737352900;36704959000;
# 4                7003860731;19634338000;57723159800;
#
#                                                Title  Year  \
# 0  Assessment of the Relevance and Reliability of...  2022
# 1  Virtual reality and neuropsychological assessm...  2016
# 2  Test-retest reliability of the virtual reality...  2021
# 3  Testing basic competency in knee arthroscopy u...  2015
# 4  Reliability and validity of the virtual realit...  2012
#
#                                         Source title Volume Issue Art. No.  \
# 0                                            Sensors     22    13     4762
# 1                      Applied Neuropsychology:Adult     23     3      NaN
# 2                               Neuroscience Letters    743   NaN   135589
# 3  Journal of Bone and Joint Surgery - American V...     97     9      NaN
# 4                                    Neuropsychology     26     4      NaN
#
#   Page start  ... Language of Original Document    Abbreviated Source Title  \
# 0        NaN  ...                       English                     Sensors
# 1        223  ...                       English   Appl. Neuropsychol. Adult
# 2        NaN  ...                       English             Neurosci. Lett.
# 3        775  ...                       English  J. Bone Jt. Surg. Am. Vol.
# 4        430  ...                       English             Neuropsychology
#
#    Document Type Publication Stage                   Open Access  Source  \
# 0        Article             Final  All Open Access, Gold, Green  Scopus
# 1        Article             Final                           NaN  Scopus
# 2        Article             Final  All Open Access, Hybrid Gold  Scopus
# 3        Article             Final                           NaN  Scopus
# 4        Article             Final                           NaN  Scopus
#
#                   EID occurence  \
# 0  2-s2.0-85132439279        57
# 1  2-s2.0-84946949625        43
# 2  2-s2.0-85098555231        43
# 3  2-s2.0-84937965598        43
# 4  2-s2.0-84871701829        43
#
#                                          keywords key_words_count
# 0  {'virtual', 'reality', 'reliability', 'mixed'}               4
# 1           {'virtual', 'reality', 'reliability'}               3
# 2           {'virtual', 'reality', 'reliability'}               3
# 3           {'virtual', 'reality', 'reliability'}               3
# 4           {'virtual', 'reality', 'reliability'}               3
#
# [5 rows x 43 columns]

# %%
#filter on the abstract column
scopus_papers_abstract_filter = filter_papers(scopus_title_filter_result, search_keywords, 'Abstract', 40)

# %%
scopus_papers_abstract_filter.sample(2)
# Out:
#      Unnamed: 0                                            Authors  \
# 83          301  Tang Y.M., Ng G.W.Y., Chia N.H., So E.H.K., Wu...
# 189         782                  Čujan Z., Fedorko G., Mikušová N.
#
#                                           Author(s) ID  \
# 83   55231482700;56611439000;57219287167;5718880315...
# 189               56317180900;25653694400;57197759300;
#
#                                                  Title  Year  \
# 83   Application of virtual reality (VR) technology...  2021
# 189  Application of virtual and augmented reality i...  2020
#
#                               Source title Volume Issue Art. No. Page start  \
# 83   Journal of Computer Assisted Learning     37     2      NaN        359
# 189                       Open Engineering     10     1      NaN        113
#
#      ... Language of Original Document    Abbreviated Source Title  \
# 83   ...                       English  J. Comput. Assisted Learn.
# 189  ...                       English                   Open Eng.
#
#      Document Type Publication Stage            Open Access  Source  \
# 83         Article             Final                    NaN  Scopus
# 189        Article             Final  All Open Access, Gold  Scopus
#
#                     EID occurence                         keywords  \
# 83   2-s2.0-85092048248        43  {virtual, reality, reliability}
# 189  2-s2.0-85081219655        43  {virtual, reality, reliability}
#
#     key_words_count
# 83                3
# 189               3
#
# [2 rows x 43 columns]

# %%
scopus_papers_abstract_filter.to_csv("filtered_papers/final_scopus_papers.csv", index=False)

# %% [markdown]
# ### Filtering the ScienceDirect papers (titles) with an acceptance occurence rate of 20%

# %%
sciencedirect_papers_title_filter = filter_papers(sciencedirect_papers, search_keywords, "title", 20)

# %%
sciencedirect_papers_title_filter.sample(2)
# Out:
#                                              author(s)  \
# 84                         Marc Parveau and Mehdi Adda
# 117  Daiana Antonio {da Silva} and Eduardo Coelho M...
#
#                                                  title  year isbn publisher  \
# 84   3iVClass: a new classification method for Virt...  2018
# 117  Reliability of directly-molded polymer surge a...  2013
#
#     address                                                url  \
# 84     2018  https://www.sciencedirect.com/science/article/...
# 117    2013  https://www.sciencedirect.com/science/article/...
#
#                                               doi  \
# 84    https://doi.org/10.1016/j.procs.2018.10.180
# 117  https://doi.org/10.1016/j.ijepes.2013.05.023
#
#                                               abstract booktitle    pages  \
# 84   For several years, augmented and virtual reali...            263-270
# 117  This technical report describes an experimenta...            488-498
#
#     numpages                  keywords location series  occurence  \
# 84                    {virtual, mixed}                         29
# 117           {immersion, reliability}                         29
#
#      key_words_count
# 84                 2
# 117                2

# %%
sciencedirect_papers_title_filter.to_csv("sciencedirect_title_filter_result.csv")

# %% [markdown]
# #### Filtering Based on the Abstract, with acceptance occurence rate of more than 40%

# %%
# load the saved title result
sciencedirect_papers_title_filter = pd.read_csv("sciencedirect_title_filter_result.csv")

# %%
sciencedirect_papers_title_filter.head(2)
# Out:
#    Unnamed: 0                                          author(s)  \
# 0          75  Hyun Kyoon Lim and Kyoungha Ji and Ye Shin Woo...
# 1         120  Rabab A. Alattas and Mariam Alzahrani and Ahme...
#
#                                                title  year  isbn  publisher  \
# 0  Test-retest reliability of the virtual reality...  2021   NaN        NaN
# 1  P118 Reliability of virtual crossmatch: Realit...  2018   NaN        NaN
#
#    address                                                url  \
# 0     2021  https://www.sciencedirect.com/science/article/...
# 1     2018  https://www.sciencedirect.com/science/article/...
#
#                                             doi  \
# 0  https://doi.org/10.1016/j.neulet.2020.135589
# 1  https://doi.org/10.1016/j.humimm.2018.07.175
#
#                                             abstract  booktitle   pages  \
# 0  No reliable quantitative and objective measure...        NaN  135589
# 1  Aim\nIn this study we evaluated the concordanc...        NaN     148
#
#    numpages                               keywords  location  series  \
# 0       NaN  {'virtual', 'reality', 'reliability'}       NaN     NaN
# 1       NaN  {'virtual', 'reality', 'reliability'}       NaN     NaN
#
#    occurence  key_words_count
# 0         43                3
# 1         43                3

# %%
#filter on the abstract column
sciencedirect_papers_abstract_filter = filter_papers(sciencedirect_papers_title_filter, search_keywords, 'abstract', 40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [121], in <cell line: 2>()
#       1 #filter on the abstract column
# ----> 2 sciencedirect_papers_abstract_filter = filter_papers(sciencedirect_papers_title_filter, search_keywords, 'abstract', 40)
#
# Input In [9], in filter_papers(document, keywords, column, acceptance_rate)
#      11 count = []
#      12 for index in range(len(document)):
#      13     #doc = document[index].lower()
# ---> 14     words_in_title = document[column].iloc[index].lower().replace(",", " ").split(" ")
#      15     keywords_found = []
#      16     for word in keywords:
#
# AttributeError: 'float' object has no attribute 'lower'
